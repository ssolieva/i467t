# %%
# Shahlo Solieva
# Analysis of I467T vs WT simulations

# %%
pwd
# Out:
# '/Users/ssolieva/Desktop/github_repo/i467t'

# %%
# import packages
import mdtraj as md
import matplotlib.pyplot as plt
import numpy as np
import itertools
import scipy.stats as stats
from matplotlib.markers import TICKDOWN
from scipy.stats import f_oneway

# %% [markdown]
# # Load in WT pdb

# %%
WT_pdb = md.load('/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/trajectories_wt/myh7-5n6a-holo-prot-masses.pdb')

# %% [markdown]
# # Functions for calculating probability, conducting t-Tests, and plotting the graphs

# %%
def calculate_probability(dists_bin, contact_number):
    '''
    Calculate probabilities from binarized distances. 
    dists_bin = binarized distances
    contact_number = residue-residue pair to look at 
    '''
    fraction_contact = []
    for t in range(len(dists_bin)):
        contacts_counter = []
        for f in range(len(dists_bin[t])):
            if dists_bin[t][f][contact_number] == True:
                contacts_counter.append(1)
        fraction_contact.append(sum(contacts_counter)/len(dists_bin[t]))
    return fraction_contact

def t_test(wt_data, i467t_data, contact_number, pairs):
    ''' conduct a t-test'''
    WT = calculate_probability(wt_data, contact_number)
    I467T = calculate_probability(i467t_data, contact_number)
    if np.var(WT) != 0 and np.var(I467T) != 0: # only run a t-Test if the variances are non-zero
        variance = [np.var(WT),np.var(I467T)]
        #print(variance, np.max(variance)/np.min(variance))
        if np.max(variance)/np.min(variance) < 4:
            #print("variance is equal:",pairs[i], variance)
            statistic, pvalue = stats.ttest_ind(a=WT, b=I467T, equal_var=True)
            if pvalue < 0.05:
                print(contact_number, "this is significant:",pairs[i], pvalue, "equal variance")
            return pvalue
        if np.max(variance)/np.min(variance) > 4:
            #print("variance is unequal:",pairs[i], variance)
            statistic, pvalue = stats.ttest_ind(a=WT, b=I467T, equal_var=False)
            if pvalue < 0.05:
                print(contact_number, "this is significant:",pairs[i], pvalue, "variance is unequal")
            return pvalue

# %%
def significance_bar(start,end,height,displaystring,linewidth = 1.2,markersize = 8,boxpad  =0.3,fontsize = 15,color = 'k'):
    # draw a line with downticks at the ends
    plt.plot([start,end],[height]*2,'-',color = color,lw=linewidth,marker = TICKDOWN,markeredgewidth=linewidth,markersize = markersize)
    # draw the text with a bounding box covering up the line
    plt.text(0.5*(start+end),height,displaystring,ha = 'center',va='center',bbox=dict(facecolor='1.', edgecolor='none',boxstyle='Square,pad='+str(boxpad)),size = fontsize)
    
def probability_graph_styleA(wt_data, i467t_data, contact_number, 
                             pairs, pvalue, rescode):
    '''
    Plots probability with significance bars.
    StyleA = ADP-neighbors, legend is at the top of the plot. 
    '''
    WT = calculate_probability(wt_data, contact_number)
    I467T = calculate_probability(i467t_data, contact_number)

    fig, ax = plt.subplots(figsize=[4,3])
    ax.bar(x = [1, 2], height=[np.average(WT),np.average(I467T)],capsize=12,tick_label=["WT", "I467T"], yerr =[np.std(WT),np.std(I467T)],alpha=0.5, color=["slateblue","gray"], label=["WT", "I467T"])
    h_wt   =np.random.uniform(0.6,   1.4,   len(WT))
    h_i467t=np.random.uniform(0.6+1, 1.4+1, len(I467T))
    ax.scatter(h_wt, WT, color="slateblue", alpha=1, s=3)
    ax.scatter(h_i467t, I467T, color="gray", alpha=1, s=3)
    plt.ylabel("$P_{contact}$"+f" ADP-{rescode}{pairs[contact_number][1]}", fontsize=14)
    plt.xticks(fontsize=14)
    plt.ylim(0,1)
    
    pvals = [pvalue]
    offset = 0.1
    for i,p in enumerate(pvals):
        if p>=0.05:
            displaystring = r'n.s.'
        elif p<0.0001:
            displaystring = r'***'
        elif p<0.001:
            displaystring = r'**'
        else:
            displaystring = r'*'
        height = 0.9
        bar_centers = [1,2]
        significance_bar(bar_centers[0],bar_centers[1],height,displaystring)
        
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.3),ncol=2, fontsize=16)
    plt.tight_layout()
    plt.show()
    
def probability_graph_styleB(wt_data, i467t_data, contact_number, 
                             pairs, pvalue, rescode1, rescode2):
    '''
    Plots probability with significance bars.
    StyleB = A loop to H helix contacts, no legend. 
    '''
    WT = calculate_probability(wt_data, contact_number)
    I467T = calculate_probability(i467t_data, contact_number)

    fig, ax = plt.subplots(figsize=[4,3])
    ax.bar(x = [1, 2], height=[np.average(WT),np.average(I467T)],capsize=12,tick_label=["WT", "I467T"], yerr =[np.std(WT),np.std(I467T)],alpha=0.5, color=["slateblue","gray"], label=["WT", "I467T"])
    h_wt   =np.random.uniform(0.6,   1.4,   len(WT))
    h_i467t=np.random.uniform(0.6+1, 1.4+1, len(I467T))
    ax.scatter(h_wt, WT, color="slateblue", alpha=1, s=3)
    ax.scatter(h_i467t, I467T, color="gray", alpha=1, s=3)
    plt.ylabel("$P_{contact}$"+f"{rescode1}{pairs[contact_number][0]}-{rescode2}{pairs[contact_number][1]}", fontsize=14)
    plt.xticks(fontsize=14)
    plt.ylim(0,1)
    
    pvals = [pvalue]
    offset = 0.1
    for i,p in enumerate(pvals):
        if p>=0.05:
            displaystring = r'n.s.'
        elif p<0.0001:
            displaystring = r'***'
        elif p<0.001:
            displaystring = r'**'
        else:
            displaystring = r'*'
        height = 0.9
        bar_centers = [1,2]
        significance_bar(bar_centers[0],bar_centers[1],height,displaystring)
        
    plt.tight_layout()
    plt.show()
    
def probability_means(wt_data, i467t_data, contact_number, pairs):
    '''
    Prints out the mean probability of contacts for a given pair of residues.
    '''
    WT = calculate_probability(wt_data, contact_number)
    I467T = calculate_probability(i467t_data, contact_number)
    print(f'{pairs[contact_number]}')
    print(f'WT average: {np.average(WT)}')
    print(f'I467T average: {np.average(I467T)}')

# %% [markdown]
# # 1. Contacts between ADP and its neighbors

# %%
set1 = [786] # ADP
set2 = [114,115,124,126,127,128,129,130,131,134,179,180,181,182,183,184,185,186,187,190,238,239,240,241,242,461,464,679]#,788]
set2_names = []
pairs = list(itertools.product(set1, set2))

# load in data from WT and mutant
wt_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/786_neighbors_binarized_distances_wildtype.npy"
i467t_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/786_neighbors_binarized_distances_I467T.npy"
WT = np.load(f"{wt_data}", allow_pickle=True)
I467T = np.load(f"{i467t_data}", allow_pickle=True)

# exclude 2 trajectories with different starting conformations
filtered_wt_data = []
for i in [0,2,3,4,5,6,7,8]:
    filtered_wt_data.append(WT[i]) 

# conduct t-test to compare WT and mutant
for i in range(len(pairs)):
    contact_number = i
    res = WT_pdb.topology.select(f'residue {pairs[contact_number][1]} and name CA')[0]
    rescode = WT_pdb.topology.atom(res).residue.code
    pvalue = t_test(filtered_wt_data, I467T, contact_number, pairs)
    #print(i, pairs[i], rescode, pvalue)
    if isinstance(pvalue, float) == True or isinstance(pvalue, int) == True:
        probability_graph_styleA(filtered_wt_data, I467T, contact_number, pairs, pvalue, rescode)
# Out:
# 0 this is significant: (786, 114) 1.7294429980216627e-12 equal variance
# 3 this is significant: (786, 126) 1.7480736637769722e-11 variance is unequal
# 4 this is significant: (786, 127) 4.456492329260329e-14 equal variance
# 5 this is significant: (786, 128) 0.0002938834715167806 variance is unequal
# 6 this is significant: (786, 129) 1.1217818199420024e-11 variance is unequal
# 8 this is significant: (786, 131) 3.201457934645715e-12 variance is unequal
# 9 this is significant: (786, 134) 4.939485426221806e-17 equal variance
# 16 this is significant: (786, 185) 0.015892745915501376 variance is unequal
# 17 this is significant: (786, 186) 5.861505778719367e-06 variance is unequal
# 27 this is significant: (786, 679) 0.0015798123543407185 equal variance

# %% [markdown]
# ## Further look into ADP-Y134:

# %%
probability_means(filtered_wt_data, I467T, 9, pairs)
# Out:
# (786, 134)
# WT average: 0.6392795946729757
# I467T average: 0.06584804440736801

# %% [markdown]
# # 2. Contacts between A loop and H helix

# %%
set1 = np.arange(126,135)
set2 = np.arange(180,191)
pairs = list(itertools.product(set1, set2))

# load in data from WT and mutant
wt_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/A_loop_HF_helix_binarized_distances_wildtype.npy"
i467t_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/A_loop_HF_helix_binarized_distances_I467T.npy"
WT = np.load(f"{wt_data}", allow_pickle=True)
I467T = np.load(f"{i467t_data}", allow_pickle=True)

# exclude 2 trajectories with different starting conformations
filtered_wt_data = []
for i in [0,2,3,4,5,6,7,8]:
    filtered_wt_data.append(WT[i]) 

# conduct t-test to compare WT and mutant
for i in range(len(pairs)):
    contact_number = i
    res1 = WT_pdb.topology.select(f'residue {pairs[contact_number][0]} and name CA')[0]
    res2 = WT_pdb.topology.select(f'residue {pairs[contact_number][1]} and name CA')[0]
    rescode1 = WT_pdb.topology.atom(res1).residue.code
    rescode2 = WT_pdb.topology.atom(res2).residue.code
    pvalue = t_test(filtered_wt_data, I467T, contact_number, pairs)
    #print(i, pairs[i], rescode, pvalue)
    if isinstance(pvalue, float) == True or isinstance(pvalue, int) == True:
        probability_graph_styleB(filtered_wt_data, I467T, contact_number, pairs, pvalue, rescode1, rescode2)
# Out:
# 1 this is significant: (126, 181) 0.02312342542236144 equal variance
# 6 this is significant: (126, 186) 1.5976037879128813e-05 variance is unequal
# 17 this is significant: (127, 186) 0.014619301138618153 variance is unequal
# 24 this is significant: (128, 182) 0.0003511479991327215 variance is unequal
# 50 this is significant: (130, 186) 0.0011254139929785499 variance is unequal
# 54 this is significant: (130, 190) 0.00018233509518473563 equal variance

# %% [markdown]
# ## Further look into W130-V186:

# %%
probability_means(filtered_wt_data, I467T, 50, pairs)
# Out:
# (130, 186)
# WT average: 0.19397876185138094
# I467T average: 0.006621641524923479

# %% [markdown]
# # 3. Aggregate simulation times

# %%
print("WT")
print(f"> number of trajectories: \t {len(filtered_wt_data)}")
print(f"> number of frames: \t\t {len(np.concatenate(filtered_wt_data))}")

print("\nI467T")
print(f"> number of trajectories: \t {len(I467T)}")
print(f"> number of frames: \t\t {len(np.concatenate(I467T))}")
# Out:
# WT
# > number of trajectories: 	 8
# > number of frames: 		 523436
#
# I467T
# > number of trajectories: 	 47
# > number of frames: 		 2387145

# %% [markdown]
# # F-test to determine if the variances are equal between WT and I467T

# %%
def f_test(wt_data, i467t_data, contact_number, pairs):
    ''' conduct f-test
    "The one-way ANOVA tests the null hypothesis that two or more groups have the same population mean. 
    The test is applied to samples from two or more groups, possibly with differing sizes."
    (https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.f_oneway.html)
    
     '''
    WT = calculate_probability(wt_data, contact_number)
    I467T = calculate_probability(i467t_data, contact_number)
    
    if np.var(WT) != 0 and np.var(I467T) != 0: # only run a t-Test if the variances are non-zero
        variance = [np.var(WT),np.var(I467T)] 
        print(f"conducting f-test for residue pair: {pairs[contact_number]}")
        F, p = f_oneway(WT, I467T) # f test from scipy to see if variances are equal 
        if p <= 0.05: # fail to reject null hypothesis 
            print(f"variances are equal: F = {F} \t p = {p} \n variances = {variance}")
        if p > 0.05: # reject null hypothesis
            print(f"variances are unequal: F = {F} \t p = {p} \n variances = {variance}")

# %%
set1 = [786] # ADP
set2 = [114,115,124,126,127,128,129,130,131,134,179,180,181,182,183,184,185,186,187,190,238,239,240,241,242,461,464,679]#,788]
set2_names = []
pairs = list(itertools.product(set1, set2))

# load in data from WT and mutant
wt_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/786_neighbors_binarized_distances_wildtype.npy"
i467t_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/786_neighbors_binarized_distances_I467T.npy"
WT = np.load(f"{wt_data}", allow_pickle=True)
I467T = np.load(f"{i467t_data}", allow_pickle=True)

# exclude 2 trajectories with different starting conformations
filtered_wt_data = []
for i in [0,2,3,4,5,6,7,8]:
    filtered_wt_data.append(WT[i]) 

# conduct f-test to compare WT and mutant variances 
contact_number = 9 # this is the ADP-Y134 pair
res = WT_pdb.topology.select(f'residue {pairs[contact_number][1]} and name CA')[0]
rescode = WT_pdb.topology.atom(res).residue.code
ftest = f_test(filtered_wt_data, I467T, contact_number, pairs)
# Out:
# conducting f-test for residue pair: (786, 134)
# variances are equal: F = 149.15505769405 	 p = 4.939485426221703e-17
#  variances = [0.03811086680602062, 0.010508325005164833]

# %%
# A loop to H helix
set1 = np.arange(126,135)
set2 = np.arange(180,191)
pairs = list(itertools.product(set1, set2))

# load in data from WT and mutant
wt_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/A_loop_HF_helix_binarized_distances_wildtype.npy"
i467t_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/A_loop_HF_helix_binarized_distances_I467T.npy"
WT = np.load(f"{wt_data}", allow_pickle=True)
I467T = np.load(f"{i467t_data}", allow_pickle=True)

# exclude 2 trajectories with different starting conformations
filtered_wt_data = []
for i in [0,2,3,4,5,6,7,8]:
    filtered_wt_data.append(WT[i]) 

# conduct t-test to compare WT and mutant
contact_number = 50 # this is the W130-V186 pair
res = WT_pdb.topology.select(f'residue {pairs[contact_number][1]} and name CA')[0]
rescode = WT_pdb.topology.atom(res).residue.code
ftest = f_test(filtered_wt_data, I467T, contact_number, pairs)
# Out:
# conducting f-test for residue pair: (130, 186)
# variances are equal: F = 159.6631512535732 	 p = 1.2790256066863279e-17
#  variances = [0.008789885011328895, 0.00019872905104218654]

# %%
def t_test(wt_data, i467t_data, contact_number, pairs):
    ''' conduct a t-test'''
    WT = calculate_probability(wt_data, contact_number)
    I467T = calculate_probability(i467t_data, contact_number)
    if np.var(WT) != 0 and np.var(I467T) != 0: # only run a t-Test if the variances are non-zero
        variance = [np.var(WT),np.var(I467T)]
        print(variance)
        print(f"conducting t-test for residue pair: {pairs[contact_number]}")
        #print(variance, np.max(variance)/np.min(variance)
            #print("variance is equal:",pairs[i], variance)
        statistic, pvalue = stats.ttest_ind(a=WT, b=I467T, equal_var=True)
        if pvalue < 0.05:
            print(contact_number, "this is significant:",pairs[contact_number], pvalue, "equal variance")
        return pvalue

# %%
# A loop to H helix
set1 = np.arange(126,135)
set2 = np.arange(180,191)
pairs = list(itertools.product(set1, set2))

# load in data from WT and mutant
wt_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/A_loop_HF_helix_binarized_distances_wildtype.npy"
i467t_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/A_loop_HF_helix_binarized_distances_I467T.npy"
WT = np.load(f"{wt_data}", allow_pickle=True)
I467T = np.load(f"{i467t_data}", allow_pickle=True)

# exclude 2 trajectories with different starting conformations
filtered_wt_data = []
for i in [0,2,3,4,5,6,7,8]:
    filtered_wt_data.append(WT[i]) 

# conduct t-test to compare WT and mutant
contact_number = 50 # this is the W130-V186 pair
print(pairs[contact_number])
res = WT_pdb.topology.select(f'residue {pairs[contact_number][1]} and name CA')[0]
rescode = WT_pdb.topology.atom(res).residue.code
ftest = f_test(filtered_wt_data, I467T, contact_number, pairs)
pvalue = t_test(filtered_wt_data, I467T, contact_number, pairs)
# Out:
# (130, 186)
# conducting f-test for residue pair: (130, 186)
# variances are equal: F = 159.6631512535732 	 p = 1.2790256066863279e-17
#  variances = [0.008789885011328895, 0.00019872905104218654]
# [0.008789885011328895, 0.00019872905104218654]
# conducting t-test for residue pair: (130, 186)
# 50 this is significant: (130, 186) 1.279025606686332e-17 equal variance

# %% [markdown]
# # Updated statistical testing: Combine t test with f test for checking if variances are equal

# %% [markdown]
# Instead of using a ratio to check for equal/unequal variances

# %%
def f_t_test(wt_data, i467t_data, contact_number, pairs):
    ''' conduct f-test
    "The one-way ANOVA tests the null hypothesis that two or more groups have the same population mean. 
    The test is applied to samples from two or more groups, possibly with differing sizes."
    (https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.f_oneway.html)
    
     '''
    WT = calculate_probability(wt_data, contact_number)
    I467T = calculate_probability(i467t_data, contact_number)
    
    if np.var(WT) != 0 and np.var(I467T) != 0: # only run a t-Test if the variances are non-zero
        variance = [np.var(WT),np.var(I467T)] 
        print(f"Conducting F-test for residue pair: {pairs[contact_number]}")
        F, p = f_oneway(WT, I467T) # f test from scipy to see if variances are equal 
        if p <= 0.05: # fail to reject null hypothesis 
            statistic, pvalue = stats.ttest_ind(a=WT, b=I467T, equal_var=True)
            if pvalue < 0.05: # only print f-test and t-test results if the t-test shows p<0.05
                print(f"\t F-test results: variances are equal: \n\t\t F = {F} \n\t\t p = {p} \n\t\t variances = {variance}")
                print(f"\t T-test results: this is significant: \n\t\tp = {pvalue}")
            return pvalue
        if p > 0.05: # reject null hypothesis
            statistic, pvalue = stats.ttest_ind(a=WT, b=I467T, equal_var=False)
            if pvalue < 0.05: # only print f-test and t-test results if the t-test shows p<0.05
                print(f"\t F-test results: variances are unequal: \n\t\t F = {F} \n\t\t p = {p} \n\t\t variances = {variance}")
                print(f"\t T-test results: this is significant: \n\t\t p = {pvalue}")
            return pvalue

# %%
set1 = [786] # ADP
set2 = [114,115,124,126,127,128,129,130,131,134,179,180,181,182,183,184,185,186,187,190,238,239,240,241,242,461,464,679]#,788]
set2_names = []
pairs = list(itertools.product(set1, set2))

# load in data from WT and mutant
wt_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/786_neighbors_binarized_distances_wildtype.npy"
i467t_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/786_neighbors_binarized_distances_I467T.npy"
WT = np.load(f"{wt_data}", allow_pickle=True)
I467T = np.load(f"{i467t_data}", allow_pickle=True)

# exclude 2 trajectories with different starting conformations
filtered_wt_data = []
for i in [0,2,3,4,5,6,7,8]:
    filtered_wt_data.append(WT[i]) 

# conduct t-test to compare WT and mutant
for i in range(len(pairs)):
    contact_number = i
    res = WT_pdb.topology.select(f'residue {pairs[contact_number][1]} and name CA')[0]
    rescode = WT_pdb.topology.atom(res).residue.code
    pvalue = f_t_test(filtered_wt_data, I467T, contact_number, pairs)
    #print(i, pairs[i], rescode, pvalue)
    if isinstance(pvalue, float) == True or isinstance(pvalue, int) == True:
        probability_graph_styleA(filtered_wt_data, I467T, contact_number, pairs, pvalue, rescode)
# Out:
# Conducting F-test for residue pair: (786, 114)
# 	 F-test results: variances are equal:
# 		 F = 83.66412187115175
# 		 p = 1.729442998021665e-12
# 		 variances = [0.004722077795965558, 0.0018892997972326819]
# 	 T-test results: this is significant:
# 		p = 1.7294429980216627e-12
# Conducting F-test for residue pair: (786, 115)
# 	 F-test results: variances are equal:
# 		 F = 32.69032806288417
# 		 p = 5.077225588600819e-07
# 		 variances = [5.947995187826316e-06, 7.336077948816032e-09]
# 	 T-test results: this is significant:
# 		p = 5.07722558860079e-07
# Conducting F-test for residue pair: (786, 126)
# 	 F-test results: variances are equal:
# 		 F = 13.178209305126188
# 		 p = 0.0006383444124707333
# 		 variances = [5.988790286655948e-05, 0.006196169814076192]
# 	 T-test results: this is significant:
# 		p = 0.0006383444124707304
# Conducting F-test for residue pair: (786, 127)
# 	 F-test results: variances are equal:
# 		 F = 103.67893027636806
# 		 p = 4.456492329260248e-14
# 		 variances = [0.0078960684471146, 0.026967101604774495]
# 	 T-test results: this is significant:
# 		p = 4.456492329260329e-14
# Conducting F-test for residue pair: (786, 128)
# 	 F-test results: variances are equal:
# 		 F = 222.93855051758723
# 		 p = 1.2416284425259197e-20
# 		 variances = [0.005173905961227596, 0.00023172859749999027]
# 	 T-test results: this is significant:
# 		p = 1.2416284425259052e-20
# Conducting F-test for residue pair: (786, 129)
# 	 F-test results: variances are equal:
# 		 F = 30.29916060322645
# 		 p = 1.0985114989082977e-06
# 		 variances = [0.003628565349424345, 0.03381531930923573]
# 	 T-test results: this is significant:
# 		p = 1.0985114989082867e-06
# Conducting F-test for residue pair: (786, 130)
# Conducting F-test for residue pair: (786, 131)
# 	 F-test results: variances are equal:
# 		 F = 14.62095597589997
# 		 p = 0.0003478412231906469
# 		 variances = [2.528649378704607e-07, 7.634627533386837e-05]
# 	 T-test results: this is significant:
# 		p = 0.00034784122319064743
# Conducting F-test for residue pair: (786, 134)
# 	 F-test results: variances are equal:
# 		 F = 149.15505769405
# 		 p = 4.939485426221703e-17
# 		 variances = [0.03811086680602062, 0.010508325005164833]
# 	 T-test results: this is significant:
# 		p = 4.939485426221806e-17
# Conducting F-test for residue pair: (786, 179)
# Conducting F-test for residue pair: (786, 180)
# Conducting F-test for residue pair: (786, 181)
# Conducting F-test for residue pair: (786, 182)
# Conducting F-test for residue pair: (786, 185)
# 	 F-test results: variances are unequal:
# 		 F = 1.0524932187082523
# 		 p = 0.3095932561955679
# 		 variances = [1.9443925936394607e-11, 6.192283729166727e-08]
# 	 T-test results: this is significant:
# 		 p = 0.015892745915501376
# Conducting F-test for residue pair: (786, 186)
# 	 F-test results: variances are equal:
# 		 F = 7.0900933455861725
# 		 p = 0.010240971960885862
# 		 variances = [0.006887272893889027, 0.08358096773669745]
# 	 T-test results: this is significant:
# 		p = 0.010240971960885853
# Conducting F-test for residue pair: (786, 187)
# Conducting F-test for residue pair: (786, 190)
# Conducting F-test for residue pair: (786, 238)
# Conducting F-test for residue pair: (786, 239)
# 	 F-test results: variances are unequal:
# 		 F = 2.9615421961814743
# 		 p = 0.09110019183442544
# 		 variances = [0.02390957728337413, 0.08790369837134628]
# 	 T-test results: this is significant:
# 		 p = 0.020148623357740002
# Conducting F-test for residue pair: (786, 240)
# Conducting F-test for residue pair: (786, 242)
# Conducting F-test for residue pair: (786, 461)
# Conducting F-test for residue pair: (786, 679)
# 	 F-test results: variances are equal:
# 		 F = 11.097759580943201
# 		 p = 0.0015798123543407205
# 		 variances = [0.017933385642277512, 0.04312752040619608]
# 	 T-test results: this is significant:
# 		p = 0.0015798123543407185

# %%
set1 = np.arange(126,135)
set2 = np.arange(180,191)
pairs = list(itertools.product(set1, set2))

# load in data from WT and mutant
wt_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/A_loop_HF_helix_binarized_distances_wildtype.npy"
i467t_data = "/Users/ssolieva/Desktop/bowman_lab/MSM_I467T/contacts_data/A_loop_HF_helix_binarized_distances_I467T.npy"
WT = np.load(f"{wt_data}", allow_pickle=True)
I467T = np.load(f"{i467t_data}", allow_pickle=True)

# exclude 2 trajectories with different starting conformations
filtered_wt_data = []
for i in [0,2,3,4,5,6,7,8]:
    filtered_wt_data.append(WT[i]) 

# conduct t-test to compare WT and mutant
for i in range(len(pairs)):
    contact_number = i
    res1 = WT_pdb.topology.select(f'residue {pairs[contact_number][0]} and name CA')[0]
    res2 = WT_pdb.topology.select(f'residue {pairs[contact_number][1]} and name CA')[0]
    rescode1 = WT_pdb.topology.atom(res1).residue.code
    rescode2 = WT_pdb.topology.atom(res2).residue.code
    pvalue = f_t_test(filtered_wt_data, I467T, contact_number, pairs)
    #print(i, pairs[i], rescode, pvalue)
    if isinstance(pvalue, float) == True or isinstance(pvalue, int) == True:
        probability_graph_styleB(filtered_wt_data, I467T, contact_number, pairs, pvalue, rescode1, rescode2)
# Out:
# Conducting F-test for residue pair: (126, 181)
# 	 F-test results: variances are equal:
# 		 F = 5.472142678442879
# 		 p = 0.023123425422361597
# 		 variances = [0.004831099930091754, 0.01856571129604907]
# 	 T-test results: this is significant:
# 		p = 0.02312342542236144
# Conducting F-test for residue pair: (126, 182)
# 	 F-test results: variances are unequal:
# 		 F = 3.529858761660648
# 		 p = 0.06577732447490073
# 		 variances = [0.0003576089911882332, 0.0011553731681071986]
# 	 T-test results: this is significant:
# 		 p = 0.01633273547285566
# Conducting F-test for residue pair: (126, 183)
# Conducting F-test for residue pair: (126, 186)
# 	 F-test results: variances are unequal:
# 		 F = 3.8969595128601173
# 		 p = 0.053595505130942384
# 		 variances = [1.2063789155160895e-09, 1.0409782972379748e-05]
# 	 T-test results: this is significant:
# 		 p = 1.5976037879128813e-05
# Conducting F-test for residue pair: (126, 187)
# Conducting F-test for residue pair: (127, 186)
# 	 F-test results: variances are unequal:
# 		 F = 1.084322959376559
# 		 p = 0.302459418256676
# 		 variances = [7.777570374518446e-11, 8.609197266359052e-08]
# 	 T-test results: this is significant:
# 		 p = 0.014619301138618153
# Conducting F-test for residue pair: (128, 181)
# Conducting F-test for residue pair: (128, 182)
# 	 F-test results: variances are unequal:
# 		 F = 2.51028066237808
# 		 p = 0.11905518402049961
# 		 variances = [3.0057642964755335e-08, 2.7049543778293415e-05]
# 	 T-test results: this is significant:
# 		 p = 0.0003511479991327215
# Conducting F-test for residue pair: (130, 186)
# 	 F-test results: variances are equal:
# 		 F = 159.6631512535732
# 		 p = 1.2790256066863279e-17
# 		 variances = [0.008789885011328895, 0.00019872905104218654]
# 	 T-test results: this is significant:
# 		p = 1.279025606686332e-17
# Conducting F-test for residue pair: (130, 190)
# 	 F-test results: variances are equal:
# 		 F = 16.19879047034305
# 		 p = 0.0001823350951847347
# 		 variances = [0.0070715872448753915, 0.006684992491878111]
# 	 T-test results: this is significant:
# 		p = 0.00018233509518473563
# Conducting F-test for residue pair: (131, 190)
# Conducting F-test for residue pair: (134, 186)
# Conducting F-test for residue pair: (134, 187)
# Conducting F-test for residue pair: (134, 190)
